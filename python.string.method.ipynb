# %%
string= "python"
print(string[0])
print(string[1])
print(string[2])
print(string[3])
print(string[4])
print(string[5])
# Out:
# p
# y
# t
# h
# o
# n

# %%
name= "student"
print(name[0])
print(name[1])
print(name[-1])
print(name[-2])
print(name[-3])
print(name[6])
# Out:
# s
# t
# t
# n
# e
# t

# %%
name= "student"
print(name[0::5])
print(name[-1::6])
print(name[::])
print(name[:7:2])
# Out:
# sn
# t
# student
# suet

# %%
name="Antim"
print(name[-1:-4:-1])
print(name[0:-4:1])
print(name[::-1])
# Out:
# mit
# A
# mitnA

# %%
name= "Nitesh sharma"
print(name[7:13:1])
print(name[0:6:1])
print(name[-13:-7:1])
# Out:
# sharma
# Nitesh
# Nitesh

# %%
name= "Antim yadav"
print(name[0:11:1])
print(name[-11:-5:1])
print(name[-1::1])
# Out:
# Antim yadav
# Antim
# v

# %%
string= "this is python class"
string.replace("python","java")
# Out:
# 'this is java class'

# %%
# capitalize() method in python

# %%
name= "my name is antim"
print(name.capitalize())
# Out:
# My name is antim

# %%
# casefold() method in python

# %%
name= "My name is Antim"
print(name.casefold())
# Out:
# my name is antim

# %%
# center() method in python

# %%
name1= "hello"
name2= "Antim"
name3= "python"
print(name1.center(10,"*"))
print(name2.center(6,"#"))
print(name3.center(8,("!")))
# Out:
# **hello***
# Antim#
# !python!

# %%
# count() method in python

# %%
str= "This is demo class. This is python class"
print(str.count("This"))
# Out:
# 2

# %%
str= "this is python and i like python. python is a famous programming language"
print(str.count("python",))
print(str.count("python", 40,60))
# Out:
# 3
# 0

# %%
# encode()method in python

# %%
str= "python"
print("python".encode())
# Out:
# b'python'

# %%
# find() method in python

# %%
str1= "I like python"
str2= "this is first text. this is second text"
print(str1.find("text", 10,12))
print(str2.find("text", 15,40))
# Out:
# -1
# 35

# %%
# endswith() method in python




str= "this is python text1. this is python text2"
print(str.endswith("text2"))
# Out:
# True

# %%
str= "this is section1. this is section3"
print(str.endswith("section3",30,40))
# Out:
# False

# %%
# expandtabs() method in python

# %%
str= "s\tt\tu\td\te\tn\tt"
print(str)
print(str.expandtabs())
print(str.expandtabs(2))
print(str.expandtabs(4))
# Out:
# s	t	u	d	e	n	t
# s       t       u       d       e       n       t
# s t u d e n t
# s   t   u   d   e   n   t

# %%
# index() method in python

# %%
str= "this is first class"
print(str.index('f'))
print(str.index('i',3,10))
# Out:
# 8
# 5

# %%
# isalnum() method in python

# %%
str= "AntimYadav455"
print(str.isalnum())
# Out:
# True

# %%
# isalpha() method in python

# %%
str= "BrotherSister"
print(str.isalpha())
# Out:
# True

# %%
# isdecimal() method in python

# %%
str= "7"
print(str.isdecimal())
# Out:
# True

# %%
# startwith() method in python

# %%
str= "this is python1. this is python2"
print(str.startswith("th"))
# Out:
# True

# %%
# isdigit() method in python

# %%
str= "43157"
print(str.isdigit())
# Out:
# True

# %%
# isidentifier() method in python

# %%
str= "Antim1234"
print(str.isidentifier())
# Out:
# True

# %%
# islower() method in python

# %%
str= "my name is antim"
print(str.islower())
# Out:
# True

# %%
# isnumeric() method in python

# %%
str= "8645329"
print(str.isnumeric())
# Out:
# True

# %%
# isprintable() method in python

# %%
str= "Sylvester"
str1= "Sylvester1234"
str2= "Sylvester1234@"
print(str.isprintable())
print(str1.isprintable())
print(str2.isprintable())
# Out:
# True
# True
# True

# %%
# isspace() method in python

# %%
str= "    "
str1= "12344"
str2= "abcd"
str3= '   '
print(str.isspace())
print(str1.isspace())
print(str2.isspace())
print(str3.isspace())
# Out:
# True
# False
# False
# True

# %%
# istitle()method in python

# %%
str= "Antim"
str1= "Antim123"
str2= "antim"
print(str.title())
print(str1.istitle())
print(str2.istitle())
# Out:
# Antim
# True
# False

# %%
# isupper() method in python

# %%
str= "DARK HORCK"
str1= "dark marry"
print(str.isupper())
print(str1.upper())
# Out:
# True
# DARK MARRY

# %%
# join() method in python

# %%
str= {"prank", "on", "videos"}
sep= "$$"
print(sep.join(str))
# Out:
# on$$prank$$videos

# %%
# lower() method in python

# %%
str= "the walking dead"
str1= "the walking dead"
print(str.islower())
print(str1.lower())
# Out:
# True
# the walking dead

# %%
# lstrip() method in python

# %%
str= "Hello"
str1= "###stranger things"
print(str.lstrip())
print(str1.lstrip("#"))
# Out:
# Hello
# stranger things

# %%
# replace() method in python

# %%
str= "i like tea"
print(str.replace("tea","coffee"))
# Out:
# i like coffee

# %%
# rfind() method in python

# %%
str= "This is first python class. This is second python class"
print(str.rfind("python class"))
# Out:
# 43

# %%
# rindex() method in python

# %%
str= "this is python class. this is another python class"
print(str.rindex("python class"))
# Out:
# 38

# %%
# rjust() method in python

# %%
str= "American Culture"
print(str.rjust(25,"!"))
# Out:
# !!!!!!!!!American Culture

# %%
# rsplit() method in python

# %%
str= "Football, Hockey, Cricket, Volleyball, Squash, Archery"
print(str.rsplit(","))
str1= "Football, Hockey, Cricket, Volleyball, Squash, Archery"
print(str1.rsplit(",",2))
# Out:
# ['Football', ' Hockey', ' Cricket', ' Volleyball', ' Squash', ' Archery']
# ['Football, Hockey, Cricket, Volleyball', ' Squash', ' Archery']

# %%
# rstrip() method in python

# %%
str= "STRANGER THINGS#######"
str1= "stranger things!"
print(str.rstrip("#"))
print(str1.rstrip())
# Out:
# STRANGER THINGS
# stranger things!

# %%
# split() method in python

# %%
str= "One$$Two$$Three$$Four"
str1= "One$$Two$$Three$$Four"
print(str.split("$$",4))
print(str1.split("$$",1))
# Out:
# ['One', 'Two', 'Three', 'Four']
# ['One', 'Two$$Three$$Four']

# %%
# splitlines() method in python

# %%
str= "one\ntwo\nthree\nfour"
str1= "one\ntwo\nthree\nfour"
print(str.splitlines(False))
print(str1.splitlines(True))
# Out:
# ['one', 'two', 'three', 'four']
# ['one\n', 'two\n', 'three\n', 'four']

# %%
# startswith() method in python

# %%
str= "this is python class. this is another python class"
str1= "this is python class. this is another python class"
print(str.startswith("py",20,25))
print(str1.startswith("",20,25))
# Out:
# False
# True

# %%
# swapcase() method in python

# %%
str= "this is python class. this is another python class"
print(str.swapcase())
# Out:
# THIS IS PYTHON CLASS. THIS IS ANOTHER PYTHON CLASS

# %%
# title() method in python

# %%
str= "my name is antim "
print(str.title())
# Out:
# My Name Is Antim

# %%
# zfill() method in python

# %%
str= "yes!"
str1= "23.44"
print(str.zfill(8))
print(str1.zfill(7))
# Out:
# 0000yes!
# 0023.44

# %%
# strip() method in python

# %%
str= "     10.55  "
print(str.strip())
# Out:
# 10.55

# %%
# format() method in python

# %%
str= "my name is {} and i am a student"
print(str.format("antim"))
# Out:
# my name is antim and i am a student

# %%
# format_map() method in python

# %%
name= "Antim"
age= 19
info= {"name": name , "age" : age}
text= "my name is {name} and my age is {age}"
print(text.format_map(info))
# Out:
# my name is Antim and my age is 19

# %%
name= "Antim"
section= 3
info= {"name" : name , "section" : section}
text= "my name is {name} and i am in section{section}"
print(text.format_map(info))
# Out:
# my name is Antim and i am in section3
